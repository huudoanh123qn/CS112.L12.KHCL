# %% [markdown]
# <a href="https://colab.research.google.com/github/anhtv26062000/CS112.L12.KHCL/blob/master/lesson_4/DOIMOI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Problem**
# ![Bai4.PNG](data:image/png;base64,...)
# #**Abstraction**
#
# #**Input**
#
# #**Output**
#
# #**Pattern Recognition**
#
# #**Pseudocode**
#
#         1.
#         2.
#         3.
